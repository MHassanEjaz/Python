# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000, 2010, 2020],
       'Exchange Rate': [65, 69, 71, 64, 62, 59, 72, 71, 75, 78, 81]}
df = pd.DataFrame(Data)

# %%
df.plot(x='Year', y='Exchange Rate', kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='Year'>

# %%
Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000, 2010, 2020],
       'Exchange Rate': [65, 69, 71, 64, 62, 59, 72, 71, 75, 78, 81]}

df = pd.DataFrame(Data, columns = ['Year', 'Exchange Rate'])
df.plot(x = 'Year', y = 'Exchange Rate', kind = 'barh')
plt.show()

# %%
Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000, 2010, 2020],
       'Exchange Rate': [65, 69, 71, 64, 62, 59, 72, 71, 75, 78, 81]}

df = pd.DataFrame(Data, columns = ['Year', 'Exchange Rate'])
df.plot(x = 'Year', y = 'Exchange Rate', kind = 'scatter')
plt.show()

# %%
Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000, 2010, 2020],
       'Exchange Rate': [65, 69, 71, 64, 62, 59, 72, 71, 75, 78, 81]}

df = pd.DataFrame(Data, columns = ['Year', 'Exchange Rate'])
plt.scatter(df['Year'], df['Exchange Rate'])
plt.show()

# %%
df.plot.pie(y='Tasks', figsize=(5,5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tasks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.plot.pie(y='Tasks', figsize=(5,5))
#       2 plt.show()
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\pandas\plotting\_core.py:1658, in PlotAccessor.pie(self, **kwargs)
#    1652 if (
#    1653     isinstance(self._parent, ABCDataFrame)
#    1654     and kwargs.get("y", None) is None
#    1655     and not kwargs.get("subplots", False)
#    1656 ):
#    1657     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1658 return self(kind="pie", **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\pandas\plotting\_core.py:988, in PlotAccessor.__call__(self, *args, **kwargs)
#     986                 y = data.columns[y]
#     987             # converted to series actually. copy to not modify
# --> 988             data = data[y].copy()
#     989             data.index.name = y
#     990 elif isinstance(data, ABCDataFrame):
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Tasks'

# %%
Data = {'Tasks': [100,500,300]}
df = pd.DataFrame(Data, columns = ['Tasks'], index = ['Pending', 'Completed', 'Ongoing'])

df.plot.pie(y='Tasks', figsize=(5,5))
plt.show()

# %%
churn_df = pd.read_csv('Churn_Modelling.csv')

# %%
churn_df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
churn_df.Geography.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Geography'>

# %%
churn_df.Geography.value_counts().plot()
# Out:
# <Axes: xlabel='Geography'>

# %%
churn_df.Geography.value_counts().plot(kind = 'barh')
# Out:
# <Axes: ylabel='Geography'>

# %%
churn_df['Exited'].value_counts().plot(kind='bar');

# %%
plt.bar(churn_df['Geography'], churn_df['EstimatedSalary'].mean(), color="cyan", edgecolor="orange")
plt.title('Geography vs Estimated Salary')
plt.show()

# %%
plt.bar(churn_df['Gender'], churn_df['Age'].max(), color="cyan", edgecolor="orange")
plt.title('Gender vs Age', fontdict = {"fontsize": 20, "color":"Green"})
plt.show()

# %%
plt.scatter(churn_df['Age'], churn_df['Tenure'])
plt.title('Scatter Plot')
plt.xlabel('This is X Axis')
plt.xlabel('This is Y Axis')
plt.show()

# %%
plt.hist(churn_df['Tenure'], bins=30)
plt.ylabel('Probability')
plt.xlabel('Tenure')
plt.show()

# %%
labels_ex = 'JavaScript', 'Java', 'Python', 'R'
sizes = [15,30,45,10]
explode_labels= (0,0.5,0,0)
fig1, ax1 = plt.subplots()


ax1.pie(sizes, explode = explode_labels, labels=labels_ex, shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %%
labels_ex = 'JavaScript', 'Java', 'Python', 'R'
sizes = [15,30,45,10]
explode_labels= (0,0.2,0.3,0)
fig1, ax1 = plt.subplots()


ax1.pie(sizes, explode = explode_labels, labels=labels_ex, shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %%
churn_df['Tenure'].plot.box()
# Out:
# <Axes: >

# %%
churn_df['Tenure'].describe()

# %%
pip install seaborn

# %%
import seaborn as sns
df = sns.load_dataset('iris')
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.kdeplot(df['sepal_length'], shade=True)
# Out:
# C:\Users\HASSAN MA\AppData\Local\Temp\ipykernel_6184\3648197333.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_length'], shade=True)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
# KDE: kernel density estimation
for col in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
    sns.kdeplot(df[col], shade=True)
# Out:
# C:\Users\HASSAN MA\AppData\Local\Temp\ipykernel_6184\1007467784.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], shade=True)
# C:\Users\HASSAN MA\AppData\Local\Temp\ipykernel_6184\1007467784.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], shade=True)
# C:\Users\HASSAN MA\AppData\Local\Temp\ipykernel_6184\1007467784.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], shade=True)
# C:\Users\HASSAN MA\AppData\Local\Temp\ipykernel_6184\1007467784.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], shade=True)

# %%
sns.distplot(df['sepal_length'])
# Out:
# C:\Users\HASSAN MA\AppData\Local\Temp\ipykernel_6184\537145680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.pairplot(df, hue='species', size=2.5);
# Out:
# C:\Users\HASSAN MA\AppData\Local\Python\pythoncore-3.10-64\lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000, 2010, 2020],
       'Exchange Rate': [65, 69, 71, 64, 62, 59, 72, 71, 75, 78, 81]}

# %%
import pandas as pd

df = pd.DataFrame(Data)
df.head(5)
# Out:
#    Year  Exchange Rate
# 0  1920             65
# 1  1930             69
# 2  1940             71
# 3  1950             64
# 4  1960             62

# %%
sns.lineplot(x=df["Year"], y=df["Exchange Rate"])
# Out:
# <Axes: xlabel='Year', ylabel='Exchange Rate'>

# %%
import matplotlib.pyplot as plt

# %%
# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

flights.head(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Load the example flights dataset and convert to long-form
#       2 flights_long = sns.load_dataset("flights")
# ----> 3 flights = flights_long.pivot("month", "year", "passengers")
#       5 flights.head(5)
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %%
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Draw a heatmap with the numeric values in each cell
#       2 f, ax = plt.subplots(figsize=(9, 6))
# ----> 3 sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
#
# NameError: name 'flights' is not defined
